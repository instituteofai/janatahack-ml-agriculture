# %% [markdown]
# # Janatahack: Machine Learning in Agriculture
#
# ## Creating a baseline model
#
# Now that we know what the data looks like, we will pre-process our data and create a baseline model.
# We will use the `scikit-learn` library to create a classifier.
#
# Since this is a multiclass classification problem, we will have to use a model that has support for this.
# Some models in `scikit-learn` that can be used for multiclass classification are:
# - ...
# - ...
# - ...

# %%
# Insert code here.
