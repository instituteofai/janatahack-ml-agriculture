# %% [markdown]
# # Janatahack: Machine Learning in Agriculture
#
# ## Introduction
#
# Janatahack is ...
#
# **Machine Learning in Agriculture** was a weekend challenge on Janatahack.
# Reading the description of the problem shows that is is a classification problem.
#
# ## Classification
#
# **Classification** is a ...
#
# Classification problems come in different types:
#
# 1. **Binary classification**
# In this kind of problem, a data point can belong to one of two possible classes.
#
# 2. **Multiclass classification**
# This is a more general case of classification where a data point can belong to onre of three or more possible classes.
#
# 3. **Multilabel classification**
# This is ...

# %% [markdown]
# ## New markdown cell
